# %%
from esmvalcore.config import CFG
from esmvalcore.dataset import Dataset
from esmvalcore.esgf import download

# %%
CFG["search_esgf"] = "always"

# %%
dataset_template_126 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP6",
    exp="ssp126",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

dataset_template_119 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP6",
    exp="ssp119",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

dataset_template_370 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP6",
    exp="ssp370",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

dataset_template_585 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP6",
    exp="ssp585",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

# %%
dataset_template_5_26 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP5",
    exp="rcp26",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

dataset_template_5_45 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP5",
    exp="rcp45",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

dataset_template_5_85 = Dataset(
    short_name="ts",
    mip="Amon",
    project="CMIP5",
    exp="rcp85",
    dataset="*",
    institute="*",
    ensemble="*",
    grid="*",
    timerange= "2001/2025",
)

# %%
datasets_126 = list(dataset_template_126.from_files())
print(f"Found {len(datasets_126)} datasets, showing the first 10:")
datasets_126[:10]
# Out:
# Found 352 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'CAS-ESM2-0',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'CAS',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'TaiESM1',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AS-RCEC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-ESM-1-REcoM',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
# ...

# %%
datasets_126
# Out:
# [Dataset:
#  {'dataset': 'CAS-ESM2-0',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'CAS',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'TaiESM1',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AS-RCEC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-ESM-1-REcoM',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp126',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'BCC-CSM2-MR',
#   'project': 'CMIP6',
# ...

# %%
datasets_119 = list(dataset_template_119.from_files())
print(f"Found {len(datasets_119)} datasets, showing the first 10:")
datasets_119[:10]
# Out:
# Found 205 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'CAMS-CSM1-0',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp119',
#   'grid': 'gn',
#   'institute': 'CAMS',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CAMS-CSM1-0',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r2i1p1f1',
#   'exp': 'ssp119',
#   'grid': 'gn',
#   'institute': 'CAMS',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'FGOALS-g3',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp119',
#   'grid': 'gn',
#   'institute': 'CAS',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanESM5-1',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp119',
#   'grid': 'gn',
#   'institute': 'CCCma',
#   'timerange': '2001/2025'},
#  Dataset:
# ...

# %%
datasets_370 = list(dataset_template_370.from_files())
print(f"Found {len(datasets_370)} datasets, showing the first 10:")
datasets_370[:10]
# Out:
# WARNING:esmvalcore.local:Configured 'default' rootpaths '/mnt/D/NSU_VKR/esmvaltool_trend/data' do not exist
# Found 436 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'TaiESM1',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp370',
#   'grid': 'gn',
#   'institute': 'AS-RCEC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp370',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r2i1p1f1',
#   'exp': 'ssp370',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r3i1p1f1',
# ...

# %%
datasets_370
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datasets_370
#
# NameError: name 'datasets_370' is not defined

# %%
datasets_585 = list(dataset_template_585.from_files())
print(f"Found {len(datasets_585)} datasets, showing the first 10:")
datasets_585[:10]
# Out:
# Found 378 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'TaiESM1',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp585',
#   'grid': 'gn',
#   'institute': 'AS-RCEC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-CM-1-1-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp585',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'AWI-ESM-1-REcoM',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp585',
#   'grid': 'gn',
#   'institute': 'AWI',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'BCC-CSM2-MR',
#   'project': 'CMIP6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1f1',
#   'exp': 'ssp585',
#   'grid': 'gn',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
# ...

# %%
dataset_template_era5 = Dataset(
   short_name="ts",
   project="native6",
   dataset="ERA5",
   tier="3",
   version="v1",
   type="reanaly",
   mip="Amon",
   start_year=1990,
   end_year=1990
)

datasets_era5 = list(dataset_template_era5.from_files())
print(f"Found {len(datasets_era5)} datasets, showing the first 10:")
datasets_era5[:10]
# Out:
# Found 1 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'ERA5',
#   'project': 'native6',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'end_year': 1990,
#   'start_year': 1990,
#   'tier': '3',
#   'type': 'reanaly',
#   'version': 'v1'}]

# %%
datasets_5_26 = list(dataset_template_5_26.from_files())
print(f"Found {len(datasets_5_26)} datasets, showing the first 10:")
datasets_5_26[:10]
# Out:
# Found 69 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'bcc-csm1-1-m',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp26',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'bcc-csm1-1',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp26',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'BNU-ESM',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp26',
#   'grid': '*',
#   'institute': 'BNU',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanESM2',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp26',
#   'grid': '*',
#   'institute': 'CCCma',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanESM2',
# ...

# %%
datasets_5_45 = list(dataset_template_5_45.from_files())
print(f"Found {len(datasets_5_45)} datasets, showing the first 10:")
datasets_5_45[:10]
# Out:
# Found 158 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'bcc-csm1-1-m',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp45',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'bcc-csm1-1',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp45',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'BNU-ESM',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp45',
#   'grid': '*',
#   'institute': 'BNU',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanCM4',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r10i1p1',
#   'exp': 'rcp45',
#   'grid': '*',
#   'institute': 'CCCma',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanCM4',
# ...

# %%
datasets_5_85 = list(dataset_template_5_85.from_files())
print(f"Found {len(datasets_5_85)} datasets, showing the first 10:")
datasets_5_85[:10]
# Out:
# Found 95 datasets, showing the first 10:
# [Dataset:
#  {'dataset': 'bcc-csm1-1-m',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp85',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'bcc-csm1-1',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp85',
#   'grid': '*',
#   'institute': 'BCC',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'BNU-ESM',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp85',
#   'grid': '*',
#   'institute': 'BNU',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanESM2',
#   'project': 'CMIP5',
#   'mip': 'Amon',
#   'short_name': 'ts',
#   'ensemble': 'r1i1p1',
#   'exp': 'rcp85',
#   'grid': '*',
#   'institute': 'CCCma',
#   'timerange': '2001/2025'},
#  Dataset:
#  {'dataset': 'CanESM2',
# ...
